# %%
import os
from langchain_openai import ChatOpenAI
os.environ["OPENAI_API_KEY"] = "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"

llm = ChatOpenAI(model='gpt-4o-mini', temperature=0)

print(llm.invoke("What is the name of earth's moon?"))
# Out:
# content='Earth\'s moon is simply called "the Moon." It is often referred to as "Luna" in scientific contexts, derived from its Latin name.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 16, 'total_tokens': 46, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CZCt53ZrODW8TctIpOoxLmKCppYBA', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--8599325f-4db7-4040-a04f-a3b127fc50be-0' usage_metadata={'input_tokens': 16, 'output_tokens': 30, 'total_tokens': 46, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
