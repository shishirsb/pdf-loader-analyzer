# %%
import os
# os.environ["OPENAI_API_KEY"] = "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"

os.environ["OPENAI_API_KEY"] = "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"

from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
from langchain_core.prompts import ChatPromptTemplate
# os.environ["GOOGLE_API_KEY"] = "AIzaSyBOr9TLK0MEq3CNamgdVIEoE7wnfHl59ik"
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_core.vectorstores import VectorStoreRetriever

# %%
# Load pdf document

# API_key = os.environ["GEMINI_API_KEY"]
#Load pdf document
loader = PyPDFLoader("pages-29-deed-sample.pdf")
pages = loader.load_and_split()
print(pages[0])
# Out:
# page_content='1
#
# Introduction:
# Registration refers to the recording of the content s of a document with a Registering
# Officer appointed by the Government. The main purpo se of registration is to ensure information
# about all deals are recorded and maintained apart f rom giving the document its authenticity. It
# gives information to the people regarding legal rig hts and obligations arising or affecting a
# particular property. The registered documents may a fterwards be of legal importance, and also
# aid in preventing fraud. The process of registering  a document is done under the provisions of
# the Registration Act, 1908. The main objects of the  law of registration are –
# (a)  to provide a conclusive proof of genuineness of doc uments;
# (b)  to afford publicity of transaction in respect of pr operties;
# (c)  to prevent fraud;
# (d)  to afford facility for ascertaining whether a prope rty has already been dealt with; and
# ...

# %%
#Chunksing the document
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=0)

docs = text_splitter.split_documents(pages)
print(type(pages))
print(type(pages[0]))

print(docs[0])
# Out:
# <class 'list'>
# <class 'langchain_core.documents.base.Document'>
# page_content='1
#
# Introduction:
# Registration refers to the recording of the content s of a document with a Registering
# Officer appointed by the Government. The main purpo se of registration is to ensure information
# about all deals are recorded and maintained apart f rom giving the document its authenticity. It
# gives information to the people regarding legal rig hts and obligations arising or affecting a
# particular property. The registered documents may a fterwards be of legal importance, and also
# aid in preventing fraud. The process of registering  a document is done under the provisions of
# the Registration Act, 1908. The main objects of the  law of registration are –
# (a)  to provide a conclusive proof of genuineness of doc uments;
# (b)  to afford publicity of transaction in respect of pr operties;
# (c)  to prevent fraud;
# ...

# %%
#Using embeddings for retrieval
# embeddings = GoogleGenerativeAIEmbeddings(model = "models/embedding-001", 
                                        #   google_api_key = os.environ['GOOGLE_API_KEY'])

from langchain_classic.chains.retrieval_qa.base import BaseRetrievalQA


embeddings = OpenAIEmbeddings()

library = FAISS.from_documents(docs, embeddings)

query_1 = "What is the purpose of this document?"

query_1_answer = library.similarity_search(query_1)
print(f"Answer to query 1: {query_1_answer[0].page_content}")

retriever = library.as_retriever()
# Out:
# Answer to query 1: 1
#
# Introduction:
# Registration refers to the recording of the content s of a document with a Registering
# Officer appointed by the Government. The main purpo se of registration is to ensure information
# about all deals are recorded and maintained apart f rom giving the document its authenticity. It
# gives information to the people regarding legal rig hts and obligations arising or affecting a
# particular property. The registered documents may a fterwards be of legal importance, and also
# aid in preventing fraud. The process of registering  a document is done under the provisions of
# the Registration Act, 1908. The main objects of the  law of registration are –
# (a)  to provide a conclusive proof of genuineness of doc uments;
# (b)  to afford publicity of transaction in respect of pr operties;
# (c)  to prevent fraud;
# (d)  to afford facility for ascertaining whether a prope rty has already been dealt with; and
# ...

# %%
llm = ChatOpenAI(model='gpt-4o-mini', temperature=0)
from langchain.chains import create_retrieval_chain

qa = create_retrieval_chain(llm=llm, retriever=retriever)

results = qa.invoke(query_1)
print(f"Response to query 1: {results['result']}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 2
#       1 llm = ChatOpenAI(model='gpt-4o-mini', temperature=0)
# ----> 2 from langchain.chains import create_retrieval_chain
#       4 qa = create_retrieval_chain(llm=llm, retriever=retriever)
#       6 results = qa.invoke(query_1)
#
# ModuleNotFoundError: No module named 'langchain.chains'
